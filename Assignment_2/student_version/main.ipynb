# %% [markdown]
# ###Mount Google Drive

# %%
# Cell 1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Part1: Implementing CNN from Scratch

# %%
# Cell 2
# %cd /content/drive/MyDrive/Deep_Learning/Assignment_2/student_version/part1-convnet

# Load CIFAR-10 data
# %cd data
# !sh get_data.sh
# %cd ..

# %% [markdown]
# Cross-check your implementation

# %%
# Cell 3
# If you get an error saying test not found, add an __init__.py file in the
# tests directory
# !python -m unittest tests.test_linear

# %% [markdown]
# Train your ConvNet

# %%
# Cell 4
# !python train.py

# %% [markdown]
# Visualize Part-1 training curve

# %%
# Cell 5
from IPython.display import display, Image
display(Image(filename='./train.png', width=500))

# %% [markdown]
# ## Zip your Part-1 submission

# %%
# Cell 6
# !python3 collect_submission.py

# %% [markdown]
# ###Part2: PyTorch

# %%
# Cell 7
# %cd /content/drive/MyDrive/Deep_Learning/Assignment_2/student_version/part2-pytorch

# %% [markdown]
# Load CIFAR-10 data

# %%
# Cell 8
# %cd data
# !sh get_data.sh
# %cd ..

# %% [markdown]
# Train your Two-Layer Net

# %%
# !python -m unittest tests.test_vanilla_cnn

# %%
# Cell 9
# !python main.py --config configs/config_twolayer.yaml

# %% [markdown]
# Train your Vanilla ConvNet

# %%
# Cell 10
# !python main.py --config configs/config_vanilla_cnn.yaml

# %% [markdown]
# Train your own model

# %%
# Cell 11
# !python main.py --config configs/config_mymodel.yaml

# %% [markdown]
# ## Zip your Part-2 submission

# %%
# Cell 12
# If you get an error saying test not found, add an __init__.py file in the
# tests directory
# !python3 collect_submission.py

# %% [markdown]
# # **Assignment 2 Writeup**
#
# - Name: Karim Ahmed Abdel Sadek
# - GT Email: ksadek3@gatech.edu
# - GT ID: 903866577

# %% [markdown]
# How does the training curve in Part-1 look like?
#
# We can see that the accuracy increases till the epoch number 9. It reaches an accuracy of 90%. In the last epoche, the accuracy decreases. This may be due to overfitting the data. We can also not that the increasing in accuracy among the epochs is steep and not smooth, suggesting that the hyperparameters are correct

# %% [markdown]
# What are the accuracies with these networks?
#
# - Two-Layer Network: \\
# Accuracy of Class 0: 0.4950 \\
# Accuracy of Class 1: 0.5840 \\
# Accuracy of Class 2: 0.0000 \\
# Accuracy of Class 3: 0.1920 \\
# Accuracy of Class 4: 0.2010 \\
# Accuracy of Class 5: 0.3150 \\
# Accuracy of Class 6: 0.4840 \\
# Accuracy of Class 7: 0.4860 \\
# Accuracy of Class 8: 0.5450 \\
# Accuracy of Class 9: 0.5540 \\
# Prec @1: 0.3856 \\
#
# \\
#
#
# - Vanilla ConvNet: \\
# Accuracy of Class 0: 0.4950 \\
# Accuracy of Class 1: 0.5840 \\
# Accuracy of Class 2: 0.0000 \\
# Accuracy of Class 3: 0.1920 \\
# Accuracy of Class 4: 0.2010 \\
# Accuracy of Class 5: 0.3150 \\
# Accuracy of Class 6: 0.4840 \\
# Accuracy of Class 7: 0.4860 \\
# Accuracy of Class 8: 0.5450 \\
# Accuracy of Class 9: 0.5540 \\
# Prec @1: 0.3856 \\
#
# \\
#
# - My ConvNet model: \\
# AAccuracy of Class 0: 0.9090\\
#
# Accuracy of Class 1: 0.9500 \\
#
# Accuracy of Class 2: 0.7960 \\
#
# Accuracy of Class 3: 0.7140 \\
#
# Accuracy of Class 4: 0.8680 \\
#
# Accuracy of Class 5: 0.7910 \\
#
# Accuracy of Class 6: 0.9070 \\
#
# Accuracy of Class 7: 0.9020 \\
#
# Accuracy of Class 8: 0.9380 \\
#
# Accuracy of Class 9: 0.9250 \\
#
# * Prec @1: 0.8700 \\
